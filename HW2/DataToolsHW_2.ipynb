# %%
import pandas as pd

# %%
# Load the dataset into Pandas and use DataFrame features to find rows with different values for text
#and text norm. Select a few rows as an example and give the complete text from both columns.

df = pd.read_csv('https://raw.githubusercontent.com/CUNY-CISC-3225/datasets/main/ljspeech.csv',sep='|')

print(df.head())
# Out:
#            id                                               text  \
# 0  LJ001-0001  Printing, in the only sense with which we are ...
# 1  LJ001-0002                     in being comparatively modern.
# 2  LJ001-0003  For although the Chinese took impressions from...
# 3  LJ001-0004  produced the block books, which were the immed...
# 4  LJ001-0005  the invention of movable metal letters in the ...
#
#                                            text_norm
# 0  Printing, in the only sense with which we are ...
# 1                     in being comparatively modern.
# 2  For although the Chinese took impressions from...
# 3  produced the block books, which were the immed...
# 4  the invention of movable metal letters in the ...

# %%
df[df['text'] != df['text_norm']]
# Out:
#                id                                               text  \
# 6      LJ001-0007  the earliest book printed with movable types, ...
# 23     LJ001-0024  But the first Bible actually dated (which also...
# 30     LJ001-0031  In 1465 Sweynheim and Pannartz began printing ...
# 33     LJ001-0034  They printed very few books in this type, thre...
# 37     LJ001-0038  while in 1470 at Paris Udalric Gering and his ...
# ...           ...                                                ...
# 13057  LJ050-0236  Thus, in the 4 months following the assassinat...
# 13058  LJ050-0237  the FBI, on 16 separate occasions, supplied a ...
# 13060  LJ050-0239            From February 11 through June 30, 1964,
# 13061  LJ050-0240  the Service had the advantage of 9,500 hours o...
# 13087  LJ050-0266     The exchange of letters dated August 31, 1964,
#
#                                                text_norm
# 6      the earliest book printed with movable types, ...
# ...

# %%
different = df[df['text'] != df['text_norm']].head()
for index, row in different.iterrows():
  print(f"Index: {index}")
  print(f"Text: {row['text']}")
  print(f"Text Norm: {row['text_norm']}")
  print("")
# Out:
# Index: 6
# Text: the earliest book printed with movable types, the Gutenberg, or "forty-two line Bible" of about 1455,
# Text Norm: the earliest book printed with movable types, the Gutenberg, or "forty-two line Bible" of about fourteen fifty-five,
#
# Index: 23
# Text: But the first Bible actually dated (which also was printed at Maintz by Peter Schoeffer in the year 1462)
# Text Norm: But the first Bible actually dated (which also was printed at Maintz by Peter Schoeffer in the year fourteen sixty-two)
#
# Index: 30
# Text: In 1465 Sweynheim and Pannartz began printing in the monastery of Subiaco near Rome,
# Text Norm: In fourteen sixty-five Sweynheim and Pannartz began printing in the monastery of Subiaco near Rome,
#
# Index: 33
# Text: They printed very few books in this type, three only; but in their very first books in Rome, beginning with the year 1468,
# ...

# %%
 value = pd . DataFrame (
{ ' a ' : [ 1 , 6 , 3 , -4, 9 , 27 ] , 'b ' : [ 8 , 1 , 99 , 31 , 53 , 5 ] } ,
index =[5 , 2 , 9 , 3 , 27 , 4 ]
)
print(value)
#Retrieve the row at index 2, then at position 2. Are they the same or different? Why?
print(value.loc[2])
print(value.iloc[2])
# Out:
#      a   b
# 5     1   8
# 2     6   1
# 9     3  99
# 3    -4  31
# 27    9  53
# 4    27   5
#  a     6
# b      1
# Name: 2, dtype: int64
#  a      3
# b      99
# Name: 9, dtype: int64

# %%
#Retrieve the value at row position 3, column index a. Use the row position 2 and column
#name ’a’ specifically. Can you perform this operation within a single indexing operation (i.e., use only
#.loc or .iloc)? Why or why not?

print(value.iloc[3,0])
print(value.loc[2,'a'])
# Out:
# -4
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-5697f64f8d9f> in <cell line: 0>()
#       4
#       5 print(value.iloc[3,0])
# ----> 6 print(value.loc[2,'a'])
#
# ...

# %%
#Find the smallest value in each column.
value[[' a ', 'b ']].min()
# Out:
#  a    -4
# b      1
# dtype: int64

# %%
#Find the smallest value in each row. Then, find the smallest value in the whole DataFrame.
value.min(axis=1)
# Out:
# 5     1
# 2     1
# 9     3
# 3    -4
# 27    9
# 4     5
# dtype: int64

# %%
#Find the smallest value in the whole DataFrame.
value.min().min()
# Out:
# -4

# %%
#How many values in column ’a’ are less than 10?
(value[' a ']<10).sum()

#7. (1 point) Retrieve all rows where the value in column ’b’ is less than the mean of column ’a’.
#8. (1 point) Retrieve all columns where the sum is an odd number.
# Out:
# 5

# %%
#Retrieve all rows where the value in column ’a’ is less than 10.
value[value[' a ']< 10]
# Out:
#      a   b
# 5     1   8
# 2     6   1
# 9     3  99
# 3    -4  31
# 27    9  53

# %%
#Retrieve all rows where the value in column ’b’ is less than the mean of column ’b’.
value[value['b ']< value['b '].mean()]
# Out:
#     a   b
# 5    1   8
# 2    6   1
# 3   -4  31
# 4   27   5

# %%
#Retrieve all rows where the value in column ’b’ is less than the mean of column ’a’.
value[value['b ']<value[' a '].mean()]
# Out:
#     a   b
# 2    6   1
# 4   27   5

# %%
#Retrieve all columns where the sum is an odd number.
#value.sum() is set on axis=0 by default and calculates the sum of each column.
#.loc allows us to use a boolean series to select columns, but .iloc does not.
value.loc[:, value.sum()%2==1]
# Out:
#     b
# 5    8
# 2    1
# 9   99
# 3   31
# 27  53
# 4    5

# %%
camera = pd.read_csv('https://raw.githubusercontent.com/CUNY-CISC-3225/datasets/main/cameras.csv')

print(camera.head())
# Out:
#                   Model  Release date  Max resolution  Low resolution  \
# 0   Canon PowerShot 350          1997           640.0             0.0
# 1   Canon PowerShot 600          1996           832.0           640.0
# 2   Canon PowerShot A10          2001          1280.0          1024.0
# 3  Canon PowerShot A100          2002          1280.0          1024.0
# 4   Canon PowerShot A20          2001          1600.0          1024.0
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0               0.0           42.0           42.0                70.0
# 1               0.0           50.0           50.0                40.0
# 2               1.0           35.0          105.0                76.0
# 3               1.0           39.0           39.0                20.0
# 4               1.0           35.0          105.0                76.0
#
#    Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
# What is the average cost of all the cameras?
avg_cost=camera['Price'].mean()
print(avg_cost)
# Out:
# 454.94093264248704

# %%
#What is the brand and model name of the most expensive camera? There may be more than one.
max_price=camera['Price'].max()
expensive_cameras=camera[camera['Price']==max_price]
print(expensive_cameras[['Brand','Model']])
# Out:
#     Brand                   Model
# 45  Canon           Canon EOS-1Ds
# 46  Canon   Canon EOS-1Ds Mark II
# 47  Canon  Canon EOS-1Ds Mark III

# %%
#Which are more common, below-average-cost cameras or above-average-cost cameras?
above_average= camera[camera['Price']>avg_cost].shape[0] #to count the number of rows
below_average=camera[camera['Price']<avg_cost].shape[0]
print(above_average)
print(below_average)
#Below average costing cameras are more common
# Out:
# 153
# 812

# %%
#Divide the DataFrame into two new DataFrames: one with cameras released on or before 2002, and one with cameras released after 2002
cameras_before2002 = camera[camera['Release date'] <= 2002]
cameras_after2002 = camera[camera['Release date'] > 2002]
print(cameras_before2002)
print(cameras_after2002)
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0     Canon PowerShot 350          1997           640.0             0.0
# 1     Canon PowerShot 600          1996           832.0           640.0
# 2     Canon PowerShot A10          2001          1280.0          1024.0
# 3    Canon PowerShot A100          2002          1280.0          1024.0
# 4     Canon PowerShot A20          2001          1600.0          1024.0
# ..                    ...           ...             ...             ...
# 960     Sony Mavica FD-88          1999          1280.0          1024.0
# 961     Sony Mavica FD-90          2000          1280.0          1280.0
# 962     Sony Mavica FD-92          2001          1472.0          1280.0
# 963     Sony Mavica FD-95          2000          1600.0          1600.0
# 964     Sony Mavica FD-97          2001          1600.0          1024.0
#
#      Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# ...

# %%
# On average, did any camera characteristics improve over time? Which ones?
before_2002means = cameras_before2002.mean(numeric_only=True)
after_2002means = cameras_after2002.mean(numeric_only=True)

improved_characteristics = before_2002means[before_2002means < after_2002means].index
print(improved_characteristics)
# Max Resolution, Low Resolution, Effective pixels, Zoom tele(T) and storage included improved over time.
# Out:
# Index(['Release date', 'Max resolution', 'Low resolution', 'Effective pixels',
#        'Zoom tele (T)', 'Storage included'],
#       dtype='object')

# %%
#On average, did any camera characteristics stay about the same? Which ones?
unchanged_characteristics = before_2002means[before_2002means.round(4) == after_2002means.round(4)].index
print("Unchanged characteristics:")
#None of the camera characteristics remained the same on average.
# Out:
# Unchanged characteristics:

# %%
#On average, did any camera characteristics get worse over time? Which ones?
worsened_characteristics = before_2002means[before_2002means > after_2002means].index
print(worsened_characteristics)
#Zoom wide, Normal Focus range, Macro focus range, Weight, Dimensions and price got worse over time.
# Out:
# Index(['Zoom wide (W)', 'Normal focus range', 'Macro focus range',
#        'Weight (inc. batteries)', 'Dimensions', 'Price'],
#       dtype='object')

# %%
#Which camera(s) have the most favorable price-to-effective-pixels ratio? There may be more than one.
#Create a new column in the DataFrame to help you answer this question.
camera['Price_Per_Effective_Pixel'] = camera['Price'] / camera['Effective pixels']
best_ratio = camera[camera['Price_Per_Effective_Pixel'] == camera['Price_Per_Effective_Pixel'].min()]
print(best_ratio[['Brand', 'Model']])
# Out:
#      Brand            Model
# 362  Kodak    Kodak DCS 14n
# 374  Kodak  Kodak DCS SLR/c
# 375  Kodak  Kodak DCS SLR/n

# %%
#Are there any missing (NaN) values in the dataset?
camera.isnull().any()
camera.isnull().sum()
#No missing values in data set.
# Out:
# Model                        0
# Release date                 0
# Max resolution               0
# Low resolution               0
# Effective pixels             0
# Zoom wide (W)                0
# Zoom tele (T)                0
# Normal focus range           0
# Macro focus range            0
# Storage included             0
# Weight (inc. batteries)      0
# Dimensions                   0
# Price                        0
# Brand                        0
# Price_Per_Effective_Pixel    0
# dtype: int64
